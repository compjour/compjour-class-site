# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import timedelta
plt.style.use('ggplot')

# %%
# Set up the data
ebay = [59.30,58.26,58.88,59.48,59.09,59.20,58.89,56.75,56.42,56.07,55.79,57.04,57.02,56.95,56.94,57.34,57.01,57.11,57.08,56.82]
yelp = [39.76,39.39,51.28,51.22,51.02,50.61,50.32,50.45,49.31,48.25,48.30,49.37,49.57,47.60,47.40,47.65,47.00,47.43,46.99,47.31]
twtr = [37.84,38.96,38.49,42.27,51.66,50.82,51.41,51.73,51.32,51.40,50.66,52.03,51.30,51.20,51.62,51.94,52.17,52.30,52.87,50.84]
for x in ebay, twtr, yelp:
    x.reverse() # data was collected in reverse-chrono order

Y_LIM = max(ebay + twtr + yelp)
X_DATES = pd.date_range(pd.datetime.strptime('2015-05-02', '%Y-%m-%d') - timedelta(days=20), periods=20).tolist()

# %% [markdown]
# ## Plotting mutliple series

# %%
plt.plot(ebay)
plt.plot(yelp)
plt.plot(twtr)

# %% [markdown]
# ## Legend
#
# You must provide a `label` for each series.

# %%
plt.plot(ebay, label = "eBay", color = "green")
plt.plot(yelp, label = "Yelp", color = "red")
plt.plot(twtr, label = "Twitter", color = "blue")
plt.legend()
