# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import timedelta
plt.style.use('ggplot')
dates = pd.date_range(pd.datetime.strptime('2015-05-02', '%Y-%m-%d') - timedelta(days=20), periods=20).tolist()
ebay = [59.30,58.26,58.88,59.48,59.09,59.20,58.89,56.75,56.42,56.07,55.79,57.04,57.02,56.95,56.94,57.34,57.01,57.11,57.08,56.82]
baba = [81.17,81.29,82.45,85.08,84.90,84.57,82.28,82.05,82.42,82.20,81.90,84.06,84.67,85.00,84.28,84.58,86.14,85.39,82.21,81.82]
twtr = [37.84,38.96,38.49,42.27,51.66,50.82,51.41,51.73,51.32,51.40,50.66,52.03,51.30,51.20,51.62,51.94,52.17,52.30,52.87,50.84]
yelp = [39.76,39.39,51.28,51.22,51.02,50.61,50.32,50.45,49.31,48.25,48.30,49.37,49.57,47.60,47.40,47.65,47.00,47.43,46.99,47.31]
for x in [ebay, baba, twtr, yelp]:
    x.reverse() # data was collected in reverse-chrono order

# %%
fig, axarr = plt.subplots(2, sharex = False)
axarr[0].plot(dates, ebay)
axarr[1].plot(dates, baba)

# %% [markdown]
# The axes each have different properties that can be adjusted accordingly

# %%
fig, axarr = plt.subplots(2, sharex = False)
axarr[0].plot(dates, ebay)
axarr[1].bar(dates, baba)
# Out:
# <Container object of 20 artists>
